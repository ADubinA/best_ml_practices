# %%
import fiftyone as fo
import fiftyone.zoo as foz

dataset = foz.load_zoo_dataset("quickstart")
session = fo.launch_app(dataset)
# Out:
# Dataset already downloaded
# Loading 'quickstart'
#  100% |█████████████████| 200/200 [3.5s elapsed, 0s remaining, 51.2 samples/s]
# Dataset 'quickstart' created
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-02d6b84a-19fe-459e-804a-a60cf3f46bc8 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-02d6b84a-19fe-459e-804a-a60cf3f46bc8 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-02d6b84a-19fe-459e-804a-a60cf3f46bc8:focus {
#   outline: none;
# }
# #fooverlay-02d6b84a-19fe-459e-804a-a60cf3f46bc8 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-02d6b84a-19fe-459e-804a-a60cf3f46bc8">
#    <div id="fooverlay-02d6b84a-19fe-459e-804a-a60cf3f46bc8" style="display: none;">
#       <button id="foactivate-02d6b84a-19fe-459e-804a-a60cf3f46bc8" >Activate</button>
#    </div>
#    <img src='data:image/png;base64,...' style="width: 100%; max-width: 1446px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-02d6b84a-19fe-459e-804a-a60cf3f46bc8");
#      var overlay = document.getElementById("fooverlay-02d6b84a-19fe-459e-804a-a60cf3f46bc8");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "02d6b84a-19fe-459e-804a-a60cf3f46bc8" },
#               subscription: "02d6b84a-19fe-459e-804a-a60cf3f46bc8"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?context=ipython&subscription=2c071aca-4ee8-4f53-b313-5871d51001e6"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
